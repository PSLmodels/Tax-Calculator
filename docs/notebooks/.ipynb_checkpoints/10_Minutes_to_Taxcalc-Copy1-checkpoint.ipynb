# %% [markdown]
# # How to use the Tax Calculator

# %% [markdown]
# This guide teaches you how to use the Open Source Policy Center's Tax Calculator. To follow along you will need the following:
#
# 1. A copy of the taxcalc package installed on your local machine.
# 2. A copy of the 2008 IRS public use file.

# %% [markdown]
# ### Import taxcalc package and other useful packages

# %%
import sys
sys.path.append("../../")
import taxcalc
from taxcalc import *
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# ### Create a 'Plan X' calculator using the default parameters

# %%
# Default Plans
#Create a Public Use File object
tax_dta = pd.read_csv("../../puf.csv")
# Create a default Parameters object
params1 = Parameters(start_year=2013)
records1 = Records(tax_dta)
# Create a Calculator
calcX = Calculator(records=records1, params=params1)
# Out:
# You loaded data for 2008.
# Your data have beeen extrapolated to 2013.

# %% [markdown]
# #### Calculate taxes for your Plan X

# %%
calcX.calc_all()

# %% [markdown]
# #### Now create an output table with intermediate and final tax variables broken down by income decile

# %%
tX = create_distribution_table(calcX, groupby="weighted_deciles", result_type="weighted_sum")

# %%
DIST_LABELS = ['Returns', 'AGI', 'Standard Deduction Filers',
                'Standard Deduction', 'Itemizers',
                'Itemized Deduction', 'Personal Exemption',
                'Taxable Income', 'Regular Tax', 'AMTI', 'AMT Filers', 'AMT',
                'Tax before Credits', 'Non-refundable Credits',
                'Tax before Refundable Credits', 'Refundable Credits',
                'Revenue']

# %%
tX.columns = DIST_LABELS

# %%
tX
# Out:
#                                    Returns               AGI  \
# (0, 14670155.836]               14,670,113  -114,498,590,791
# (14670155.836, 29340311.672]    14,669,507   123,815,090,766
# (29340311.672, 44010467.509]    14,670,315   219,559,116,870
# (44010467.509, 58680623.345]    14,669,705   318,600,970,871
# (58680623.345, 73350779.181]    14,668,004   436,131,583,837
# (73350779.181, 88020935.0171]   14,672,820   580,546,331,235
# (88020935.0171, 102691090.853]  14,669,154   774,124,638,787
# (102691090.853, 117361246.69]   14,671,492 1,044,821,495,561
# (117361246.69, 132031402.526]   14,668,264 1,457,239,098,273
# (132031402.526, 146701558.362]  14,672,184 4,439,063,165,896
# sums                           146,701,558 9,279,402,901,304
#
#                                 Standard Deduction Filers  Standard Deduction  \
# (0, 14670155.836]                               9,035,754      73,539,571,201
# (14670155.836, 29340311.672]                   13,904,819     102,531,131,901
# (29340311.672, 44010467.509]                   13,680,811     110,324,246,846
# (44010467.509, 58680623.345]                   13,294,056     111,244,750,194
# (58680623.345, 73350779.181]                   12,278,098     104,257,665,011
# (73350779.181, 88020935.0171]                  10,868,164      97,549,990,910
# (88020935.0171, 102691090.853]                  9,170,779      89,832,361,446
# (102691090.853, 117361246.69]                   7,420,493      82,808,521,081
# (117361246.69, 132031402.526]                   4,888,618      58,464,953,859
# (132031402.526, 146701558.362]                  1,965,831      23,943,914,321
# sums                                           96,507,423     854,497,106,770
#
#                                 Itemizers  Itemized Deduction  \
# (0, 14670155.836]                 405,178       6,651,590,837
# (14670155.836, 29340311.672]                14,645,549
# (29340311.672, 44010467.509]               338,588,983
# (44010467.509, 58680623.345]             1,576,117,287
# (58680623.345, 73350779.181]             3,560,713,767
# (73350779.181, 88020935.0171]            5,172,257,142
# (88020935.0171, 102691090.853]           7,341,831,336
# (102691090.853, 117361246.69]            9,734,578,367
# (117361246.69, 132031402.526]           10,857,533,237
# (132031402.526, 146701558.362]          30,576,949,530
# sums                                    69,177,872,706
#
#                                 Tax before Refundable Credits  \
# (0, 14670155.836]                               3,659,263,725
# (14670155.836, 29340311.672]                    2,569,855,186
# (29340311.672, 44010467.509]                    6,621,478,824
# (44010467.509, 58680623.345]                   11,221,235,393
# (58680623.345, 73350779.181]                   21,544,515,350
# (73350779.181, 88020935.0171]                  36,643,626,546
# (88020935.0171, 102691090.853]                 59,897,962,377
# (102691090.853, 117361246.69]                  94,479,701,071
# (117361246.69, 132031402.526]                 155,023,503,473
# (132031402.526, 146701558.362]              1,026,300,166,375
# sums                                        1,417,961,308,319
#
#                                 Refundable Credits           Revenue
# (0, 14670155.836]                    4,437,567,728      -778,304,003
# (14670155.836, 29340311.672]        16,130,905,378   -13,561,050,192
# (29340311.672, 44010467.509]        27,046,597,934   -20,425,119,110
# (44010467.509, 58680623.345]        23,740,600,163   -12,519,364,770
# (58680623.345, 73350779.181]        16,484,241,386     5,060,273,963
# (73350779.181, 88020935.0171]        8,158,156,561    28,485,469,985
# (88020935.0171, 102691090.853]       3,759,156,371    56,138,806,006
# (102691090.853, 117361246.69]        1,989,258,026    92,490,443,045
# (117361246.69, 132031402.526]        1,076,266,562   153,947,236,912
# (132031402.526, 146701558.362]         555,549,883 1,025,744,616,492
# sums                               103,378,299,991 1,314,583,008,328

# %% [markdown]
# #### Then create a 'Plan Y' calculator using a parameter file that contains plan Y tax law.

# %% [markdown]
# ##### In this case, we are using an example param file in which the state and local deduction haircut has been set to 100%, effectively repealing the deduction for state and local taxes.

# %%
# User specified Plans
params2 = Parameters(start_year=2013)
#Create a Public Use File object
tax_dta = pd.read_csv("../../puf.csv")
# Create a default Parameters object
records2 = Records(tax_dta)

myvars = {}
myvars['_ID_StateLocalTax_HC'] = [1]
user_mods = {2013: myvars}

# Create a Calculator
calcY = calculator(params=params2, records=records2, mods=user_mods)
# Out:
# Modifications are for year 2013 and Records are for year 2008. Records will be advanced to year 2013

# %%
calcY.calc_all()

# %% [markdown]
# #### Create an output table with intermediate and final tax variables broken down by income decile

# %%
tY = create_distribution_table(calcY, groupby="weighted_deciles", result_type="weighted_sum")

# %%
tY.columns = DIST_LABELS

# %%
tY
# Out:
#                                    Returns               AGI  \
# (0, 14670155.836]               14,670,113  -114,498,590,791
# (14670155.836, 29340311.672]    14,669,507   123,815,090,766
# (29340311.672, 44010467.509]    14,670,315   219,559,116,870
# (44010467.509, 58680623.345]    14,669,705   318,600,970,871
# (132031402.526, 146701558.362]         551,601,538 1,089,370,932,240
# sums                               102,823,479,748 1,402,900,694,323

# %% [markdown]
# #### Create a difference table between plan X and plan Y

# %%
tdiff2013 = create_difference_table(calcX, calcY, groupby="weighted_deciles")

# %%
DIFF_TABLE_LABELS = ["Inds. w/ Tax Cut", "Inds. w/ Tax Increase", "Count",
                     "Mean Tax Difference", "Total Tax Difference",
                     "%age Tax Increase", "%age Tax Decrease",
                     "Share of Overall Change"]
tdiff2013.columns = DIFF_TABLE_LABELS

# %%
tdiff2013
# Out:
#                                 Inds. w/ Tax Cut  Inds. w/ Tax Increase  \
# (0, 14670155.836]                             20                  5,511
# (14670155.836, 29340311.672]                   0                 43,018
# (29340311.672, 44010467.509]                   0                389,716
# (44010467.509, 58680623.345]                   0                868,478
# (58680623.345, 73350779.181]                 376              2,003,839
# (73350779.181, 88020935.0171]                 42              3,541,485
# (88020935.0171, 102691090.853]                21              5,321,181
# (102691090.853, 117361246.69]                989              7,150,398
# (117361246.69, 132031402.526]              2,443              9,695,682
# (132031402.526, 146701558.362]           228,502             12,377,419
# sums                                     232,393             41,396,727
#
#                                      Count Mean Tax Difference  \
# (0, 14670155.836]               14,670,113                   0
# (14670155.836, 29340311.672]    14,669,507                   0
# (29340311.672, 44010467.509]    14,670,315                   4
# (44010467.509, 58680623.345]    14,669,705                  14
# (58680623.345, 73350779.181]    14,668,004                  39
# (73350779.181, 88020935.0171]   14,672,820                  93
# (88020935.0171, 102691090.853]  14,669,154                 226
# (102691090.853, 117361246.69]   14,671,492                 439
# (117361246.69, 132031402.526]   14,668,264                 868
# (132031402.526, 146701558.362]  14,672,184               4,337
# sums                           146,701,558                 n/a
#
#                                 Total Tax Difference %age Tax Increase  \
# (0, 14670155.836]                            839,344             0.04%
# (14670155.836, 29340311.672]               2,603,056             0.29%
# (29340311.672, 44010467.509]              53,516,350             2.66%
# (44010467.509, 58680623.345]             205,348,713             5.92%
# (58680623.345, 73350779.181]             572,055,329            13.66%
# (73350779.181, 88020935.0171]          1,368,977,441            24.14%
# (88020935.0171, 102691090.853]         3,318,882,487            36.27%
# (102691090.853, 117361246.69]          6,443,876,886            48.74%
# (117361246.69, 132031402.526]         12,725,270,640            66.10%
# (132031402.526, 146701558.362]        63,626,315,748            84.36%
# sums                                  88,317,685,996               n/a
#
#                                %age Tax Decrease Share of Overall Change
# (0, 14670155.836]                          0.00%                   0.00%
# (14670155.836, 29340311.672]               0.00%                   0.00%
# (29340311.672, 44010467.509]               0.00%                   0.06%
# (44010467.509, 58680623.345]               0.00%                   0.23%
# (58680623.345, 73350779.181]               0.00%                   0.65%
# (73350779.181, 88020935.0171]              0.00%                   1.55%
# (88020935.0171, 102691090.853]             0.00%                   3.76%
# (102691090.853, 117361246.69]              0.01%                   7.30%
# (117361246.69, 132031402.526]              0.02%                  14.41%
# (132031402.526, 146701558.362]             1.56%                  72.04%
# sums                                         n/a                 100.00%

# %% [markdown]
# #### Increment years to 2016 and create another difference table

# %%
for i in range(3):
    calcX.increment_year()
    calcY.increment_year()

print calcX.current_year
print calcY.current_year
calcX.calc_all()
calcY.calc_all()
# Out:
# 2016
# 2016

# %%
tdiff2016 = create_difference_table(calcX, calcY, groupby="weighted_deciles")
tdiff2016.columns = DIFF_TABLE_LABELS
tdiff2016
# Out:
#                                 Inds. w/ Tax Cut  Inds. w/ Tax Increase  \
# (0, 15271290.822]                             76                  5,791
# (15271290.822, 30542581.643]                   0                 56,393
# (30542581.643, 45813872.465]                   0                433,838
# (45813872.465, 61085163.286]                  32                994,234
# (61085163.286, 76356454.108]                 402              2,336,250
# (76356454.108, 91627744.93]                   87              3,959,723
# (91627744.93, 106899035.751]                  66              5,779,484
# (106899035.751, 122170326.573]             1,018              7,847,062
# (122170326.573, 137441617.395]             6,103             10,390,689
# (137441617.395, 152712908.216]           235,231             13,043,926
# sums                                     243,016             44,847,390
#
#                                      Count Mean Tax Difference  \
# (0, 15271290.822]               15,270,892                   0
# (15271290.822, 30542581.643]    15,270,779                   0
# (30542581.643, 45813872.465]    15,270,329                   5
# (45813872.465, 61085163.286]    15,271,562                  17
# (61085163.286, 76356454.108]    15,269,499                  50
# (76356454.108, 91627744.93]     15,272,293                 116
# (91627744.93, 106899035.751]    15,271,485                 283
# (106899035.751, 122170326.573]  15,273,010                 527
# (122170326.573, 137441617.395]  15,271,454               1,056
# (137441617.395, 152712908.216]  15,271,605               4,922
# sums                           152,712,908                 n/a
#
#                                 Total Tax Difference %age Tax Increase  \
# (0, 15271290.822]                            912,766             0.04%
# (15271290.822, 30542581.643]               4,406,457             0.37%
# (30542581.643, 45813872.465]              74,766,325             2.84%
# (45813872.465, 61085163.286]             259,512,661             6.51%
# (61085163.286, 76356454.108]             769,816,486            15.30%
# (76356454.108, 91627744.93]            1,777,394,991            25.93%
# (91627744.93, 106899035.751]           4,317,872,123            37.84%
# (106899035.751, 122170326.573]         8,046,876,927            51.38%
# (122170326.573, 137441617.395]        16,121,981,222            68.04%
# (137441617.395, 152712908.216]        75,169,687,114            85.41%
# sums                                 106,543,227,071               n/a
#
#                                %age Tax Decrease Share of Overall Change
# (0, 15271290.822]                          0.00%                   0.00%
# (15271290.822, 30542581.643]               0.00%                   0.00%
# (30542581.643, 45813872.465]               0.00%                   0.07%
# (45813872.465, 61085163.286]               0.00%                   0.24%
# (61085163.286, 76356454.108]               0.00%                   0.72%
# (76356454.108, 91627744.93]                0.00%                   1.67%
# (91627744.93, 106899035.751]               0.00%                   4.05%
# (106899035.751, 122170326.573]             0.01%                   7.55%
# (122170326.573, 137441617.395]             0.04%                  15.13%
# (137441617.395, 152712908.216]             1.54%                  70.55%
# sums                                         n/a                 100.00%
