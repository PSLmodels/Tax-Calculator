# %% [markdown]
# # How to use the Tax Calculator

# %% [markdown]
# THIS DOCUMENT IS STILL IN PROGRESS!

# %% [markdown]
# ### This is where we can put some great documentation

# %% [markdown]
# ### Import taxcalc package and other useful packages

# %%
import sys
sys.path.append("../../")
import taxcalc
from taxcalc import *
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# ### Create a 'Plan X' calculator using the default parameters

# %%
# Default Plans
#Create a Public Use File object
tax_dta = pd.read_csv("../../puf.csv")
# Create a default Parameters object
params = Parameters(start_year=2013)
records = Records(tax_dta)
# Create a Calculator
calcX = Calculator(records=records, parameters=params)
# Out:
# You loaded data for 2008.
# Your data have beeen extrapolated to 2013.

# %% [markdown]
# #### Calculate taxes for your Plan X

# %%
calcX.calc_all()

# %% [markdown]
# #### Create an output table with intermediate and final tax variables broken down by income decile

# %%
tX = create_distribution_table(calcY, groupby="weighted_deciles", result_type="weighted_sum")

# %%
tX
# Out:
#                                             c00100  num_returns_StandardDed  \
# bins
# (0, 1425774560.8]               -4,739,332,884,423              900,766,509
# (1425774560.8, 2851549121.6]    11,439,145,145,789            1,352,875,745
# (2851549121.6, 4277323682.4]    20,013,685,084,223            1,320,592,109
# (4277323682.4, 5703098243.2]    29,057,266,520,979            1,274,553,040
# (5703098243.2, 7128872804]      39,788,028,336,871            1,178,885,222
# (7128872804, 8554647364.8]      52,960,707,853,394            1,039,002,965
# (8554647364.8, 9980421925.6]    70,679,737,673,251              865,719,713
# (9980421925.6, 11406196486.4]   95,223,638,072,133              677,506,275
# (11406196486.4, 12831971047.2] 132,641,000,205,154              452,786,090
# (12831971047.2, 14257745608]   385,875,110,465,727              172,137,492
#
#                                         _standard  num_returns_ItemDed  \
# bins
# (0, 1425774560.8]               7,142,351,973,374           39,863,463
# (1425774560.8, 2851549121.6]    9,997,565,409,834           63,656,617
# (2851549121.6, 4277323682.4]   10,745,637,164,779          102,261,573
# (4277323682.4, 5703098243.2]   10,665,267,168,003          149,508,463
# (5703098243.2, 7128872804]     10,069,399,102,755          246,031,476
# (7128872804, 8554647364.8]      9,272,067,366,988          385,972,813
# (8554647364.8, 9980421925.6]    8,431,118,653,138          559,866,387
# (9980421925.6, 11406196486.4]   7,436,586,637,325          748,058,538
# (11406196486.4, 12831971047.2]  5,383,311,014,541          972,861,796
# (12831971047.2, 14257745608]    2,093,599,131,548        1,253,835,157
#
#                                            c04470             c04600  \
# bins
# (0, 1425774560.8]                 649,016,360,124  5,009,587,131,900
# (1425774560.8, 2851549121.6]    1,032,173,306,322  7,215,315,650,400
# (2851549121.6, 4277323682.4]    1,737,135,021,157  9,792,028,868,700
# (4277323682.4, 5703098243.2]    2,380,154,237,563 10,516,746,095,700
# (5703098243.2, 7128872804]      3,863,625,034,591 10,995,979,659,600
# (7128872804, 8554647364.8]      6,200,805,244,434 11,105,840,584,800
# (8554647364.8, 9980421925.6]    9,866,458,964,384 11,890,572,209,100
# (9980421925.6, 11406196486.4]  14,663,632,526,078 13,378,076,130,900
# (11406196486.4, 12831971047.2] 22,689,349,139,189 14,646,882,287,700
# (12831971047.2, 14257745608]   57,429,083,371,550 14,120,104,750,134
#
#                                             c04800             c05200  \
# bins
# (0, 1425774560.8]                   71,750,395,878      7,175,039,588
# (1425774560.8, 2851549121.6]       551,667,865,463     55,197,602,455
# (2851549121.6, 4277323682.4]     2,969,542,314,105    298,154,431,962
# (4277323682.4, 5703098243.2]     7,805,985,454,271    834,649,357,196
# (5703098243.2, 7128872804]      15,774,073,793,452  1,859,813,935,024
# (7128872804, 8554647364.8]      26,821,316,937,741  3,317,254,747,244
# (8554647364.8, 9980421925.6]    40,799,056,546,353  5,359,499,476,928
# (9980421925.6, 11406196486.4]   59,879,347,254,149  8,558,012,936,036
# (11406196486.4, 12831971047.2]  90,086,561,246,382 13,566,070,894,542
# (12831971047.2, 14257745608]   312,900,326,986,168 84,690,245,768,543
#
#                                 num_returns_AMT            c09600  \
# bins
# (0, 1425774560.8]                             0                 0
# (1425774560.8, 2851549121.6]                  0                 0
# (2851549121.6, 4277323682.4]                  0                 0
# (4277323682.4, 5703098243.2]                  0                 0
# (5703098243.2, 7128872804]                    0                 0
# (7128872804, 8554647364.8]                    0                 0
# (8554647364.8, 9980421925.6]            243,498       142,681,337
# (9980421925.6, 11406196486.4]         2,684,723     3,264,079,923
# (11406196486.4, 12831971047.2]        7,117,683    14,530,848,896
# (12831971047.2, 14257745608]        274,041,954 1,883,693,302,222
#
#                                            c05800             c09200  \
# bins
# (0, 1425774560.8]                   2,905,824,313    125,646,296,731
# (1425774560.8, 2851549121.6]       49,992,102,697    275,729,936,660
# (2851549121.6, 4277323682.4]      288,811,926,517    623,849,530,557
# (4277323682.4, 5703098243.2]      816,554,512,333    981,733,068,611
# (5703098243.2, 7128872804]      1,830,446,443,158  1,853,316,317,901
# (7128872804, 8554647364.8]      3,260,474,241,198  3,180,034,602,984
# (8554647364.8, 9980421925.6]    5,258,713,463,403  5,064,034,162,492
# (9980421925.6, 11406196486.4]   8,382,549,155,182  8,099,856,363,431
# (11406196486.4, 12831971047.2] 13,279,117,924,889 13,030,262,543,335
# (12831971047.2, 14257745608]   77,742,553,840,925 81,646,893,435,040
#
#                                          _refund            c07100  \
# bins
# (0, 1425774560.8]                408,385,507,435        55,109,730
# (1425774560.8, 2851549121.6]   1,579,568,092,317       370,321,855
# (2851549121.6, 4277323682.4]   2,544,804,114,426    11,374,533,739
# (4277323682.4, 5703098243.2]   2,322,772,067,707    81,442,734,607
# (5703098243.2, 7128872804]     1,791,249,783,533   244,891,249,438
# (7128872804, 8554647364.8]       909,581,005,273   388,359,599,711
# (8554647364.8, 9980421925.6]     390,523,996,457   598,475,961,325
# (9980421925.6, 11406196486.4]    212,773,682,222   832,588,494,488
# (11406196486.4, 12831971047.2]   103,509,504,296   960,854,659,443
# (12831971047.2, 14257745608]      54,769,698,540 2,172,841,817,296
#
#                                          _ospctax          s006
# bins
# (0, 1425774560.8]                -282,739,210,704 1,425,668,475
# (1425774560.8, 2851549121.6]   -1,303,838,155,657 1,425,606,123
# (2851549121.6, 4277323682.4]   -1,920,954,583,868 1,426,035,581
# (4277323682.4, 5703098243.2]   -1,341,038,999,096 1,425,485,175
# (5703098243.2, 7128872804]         62,066,534,369 1,425,937,720
# (7128872804, 8554647364.8]      2,270,453,597,711 1,425,898,197
# (8554647364.8, 9980421925.6]    4,673,510,166,035 1,425,703,717
# (9980421925.6, 11406196486.4]   7,887,082,681,209 1,425,692,538
# (11406196486.4, 12831971047.2] 12,926,753,039,040 1,425,647,886
# (12831971047.2, 14257745608]   81,592,123,736,500 1,426,070,196

# %%
print (calcX._ospctax*calcX.s006).sum()
# Out:
# 1.27263632522e+12

# %% [markdown]
# ### Then create a 'Plan Y' calculator using the default tax law parameters and one-off tax law mods

# %%
# User specified Plans
user_mods = '{"_II_rt7": [0.40]}'
params2 = Parameters(start_year=2013)
#Create a Public Use File object
tax_dta2 = pd.read_csv("../../puf.csv")
# Create a default Parameters object
records2 = Records(tax_dta)

# Create a Calculator
calcY = calculator(parameters=params2, records=records2, mods=user_mods)

# %%
calcY.calc_all()

# %% [markdown]
# #### Create an output table with intermediate and final tax variables broken down by income decile

# %%
tY = create_distribution_table(calcY, groupby="weighted_deciles", result_type="weighted_sum")

# %%
tY
# Out:
#                                             c00100  num_returns_StandardDed  \
# bins
# (0, 1425774560.8]               -4,739,332,884,423              900,766,509
# (1425774560.8, 2851549121.6]    11,439,145,145,789            1,352,875,745
# (2851549121.6, 4277323682.4]    20,013,685,084,223            1,320,592,109
# (4277323682.4, 5703098243.2]    29,057,266,520,979            1,274,553,040
# (5703098243.2, 7128872804]      39,788,028,336,871            1,178,885,222
# (7128872804, 8554647364.8]      52,960,707,853,394            1,039,002,965
# (8554647364.8, 9980421925.6]    70,679,737,673,251              865,719,713
# (9980421925.6, 11406196486.4]   95,223,638,072,133              677,506,275
# (11406196486.4, 12831971047.2] 132,641,000,205,154              452,786,090
# (12831971047.2, 14257745608]   385,875,110,465,727              172,137,492
#
#                                         _standard  num_returns_ItemDed  \
# bins
# (0, 1425774560.8]               7,142,351,973,374           39,863,463
# (1425774560.8, 2851549121.6]    9,997,565,409,834           63,656,617
# (2851549121.6, 4277323682.4]   10,745,637,164,779          102,261,573
# (4277323682.4, 5703098243.2]   10,665,267,168,003          149,508,463
# (5703098243.2, 7128872804]     10,069,399,102,755          246,031,476
# (7128872804, 8554647364.8]      9,272,067,366,988          385,972,813
# (8554647364.8, 9980421925.6]    8,431,118,653,138          559,866,387
# (9980421925.6, 11406196486.4]   7,436,586,637,325          748,058,538
# (11406196486.4, 12831971047.2]  5,383,311,014,541          972,861,796
# (12831971047.2, 14257745608]    2,093,599,131,548        1,253,835,157
#
#                                            c04470             c04600  \
# bins
# (0, 1425774560.8]                 649,016,360,124  5,009,587,131,900
# (1425774560.8, 2851549121.6]    1,032,173,306,322  7,215,315,650,400
# (2851549121.6, 4277323682.4]    1,737,135,021,157  9,792,028,868,700
# (4277323682.4, 5703098243.2]    2,380,154,237,563 10,516,746,095,700
# (5703098243.2, 7128872804]      3,863,625,034,591 10,995,979,659,600
# (7128872804, 8554647364.8]      6,200,805,244,434 11,105,840,584,800
# (8554647364.8, 9980421925.6]    9,866,458,964,384 11,890,572,209,100
# (9980421925.6, 11406196486.4]  14,663,632,526,078 13,378,076,130,900
# (11406196486.4, 12831971047.2] 22,689,349,139,189 14,646,882,287,700
# (12831971047.2, 14257745608]   57,429,083,371,550 14,120,104,750,134
#
#                                             c04800             c05200  \
# bins
# (0, 1425774560.8]                   71,750,395,878      7,175,039,588
# (1425774560.8, 2851549121.6]       551,667,865,463     55,197,602,455
# (2851549121.6, 4277323682.4]     2,969,542,314,105    298,154,431,962
# (4277323682.4, 5703098243.2]     7,805,985,454,271    834,649,357,196
# (5703098243.2, 7128872804]      15,774,073,793,452  1,859,813,935,024
# (7128872804, 8554647364.8]      26,821,316,937,741  3,317,254,747,244
# (8554647364.8, 9980421925.6]    40,799,056,546,353  5,359,499,476,928
# (9980421925.6, 11406196486.4]   59,879,347,254,149  8,558,012,936,036
# (11406196486.4, 12831971047.2]  90,086,561,246,382 13,566,070,894,542
# (12831971047.2, 14257745608]   312,900,326,986,168 85,231,198,840,606
#
#                                 num_returns_AMT            c09600  \
# bins
# (0, 1425774560.8]                             0                 0
# (1425774560.8, 2851549121.6]                  0                 0
# (2851549121.6, 4277323682.4]                  0                 0
# (4277323682.4, 5703098243.2]                  0                 0
# (5703098243.2, 7128872804]                    0                 0
# (7128872804, 8554647364.8]                    0                 0
# (8554647364.8, 9980421925.6]            243,498       142,681,337
# (9980421925.6, 11406196486.4]         2,684,723     3,264,079,923
# (11406196486.4, 12831971047.2]        7,117,683    14,530,848,896
# (12831971047.2, 14257745608]        273,516,960 1,877,477,383,810
#
#                                            c05800             c09200  \
# bins
# (0, 1425774560.8]                   2,905,824,313    125,646,296,731
# (1425774560.8, 2851549121.6]       49,992,102,697    275,729,936,660
# (2851549121.6, 4277323682.4]      288,811,926,517    623,849,530,557
# (4277323682.4, 5703098243.2]      816,554,512,333    981,733,068,611
# (5703098243.2, 7128872804]      1,830,446,443,158  1,853,316,317,901
# (7128872804, 8554647364.8]      3,260,474,241,198  3,180,034,602,984
# (8554647364.8, 9980421925.6]    5,258,713,463,403  5,064,034,162,492
# (9980421925.6, 11406196486.4]   8,382,549,155,182  8,099,856,363,431
# (11406196486.4, 12831971047.2] 13,279,117,924,889 13,030,262,543,335
# (12831971047.2, 14257745608]   78,075,472,270,850 81,979,532,244,715
#
#                                          _refund            c07100  \
# bins
# (0, 1425774560.8]                408,385,507,435        55,109,730
# (1425774560.8, 2851549121.6]   1,579,568,092,317       370,321,855
# (2851549121.6, 4277323682.4]   2,544,804,114,426    11,374,533,739
# (4277323682.4, 5703098243.2]   2,322,772,067,707    81,442,734,607
# (5703098243.2, 7128872804]     1,791,249,783,533   244,891,249,438
# (7128872804, 8554647364.8]       909,581,005,273   388,359,599,711
# (8554647364.8, 9980421925.6]     390,523,996,457   598,475,961,325
# (9980421925.6, 11406196486.4]    212,773,682,222   832,588,494,488
# (11406196486.4, 12831971047.2]   103,509,504,296   960,854,659,443
# (12831971047.2, 14257745608]      54,769,698,540 2,173,121,437,548
#
#                                          _ospctax          s006
# bins
# (0, 1425774560.8]                -282,739,210,704 1,425,668,475
# (1425774560.8, 2851549121.6]   -1,303,838,155,657 1,425,606,123
# (2851549121.6, 4277323682.4]   -1,920,954,583,868 1,426,035,581
# (4277323682.4, 5703098243.2]   -1,341,038,999,096 1,425,485,175
# (5703098243.2, 7128872804]         62,066,534,369 1,425,937,720
# (7128872804, 8554647364.8]      2,270,453,597,711 1,425,898,197
# (8554647364.8, 9980421925.6]    4,673,510,166,035 1,425,703,717
# (9980421925.6, 11406196486.4]   7,887,082,681,209 1,425,692,538
# (11406196486.4, 12831971047.2] 12,926,753,039,040 1,425,647,886
# (12831971047.2, 14257745608]   81,924,762,546,174 1,426,070,196

# %% [markdown]
# #### Create a difference table between plan X and plan Y

# %%
tdiff = create_difference_table(calc1, calc2, groupby="agi_bins")

# %%
tdiff
# Out:
#                            tax_cut    tax_inc       count          mean  \
# bins
# (-100000000000000, 0]            0          0   208943736      0.000000
# (0, 9999]                        0          0  2416798214      0.000000
# (9999, 19999]                    0          0  2289136406      0.000000
# (19999, 29999]                   0          0  1859220326      0.000000
# (29999, 39999]                   0          0  1458517866      0.000000
# (39999, 49999]                   0          0  1095710196      0.000000
# (49999, 74999]                   0          0  1922982230      0.000000
# (74999, 99999]                   0   12391487  1179289469     14.211983
# (99999, 200000]                998  166853146  1391525415    718.423979
# (200000, 100000000000000]    23471  351079961   435621750  11991.022880
#
#                              tot_change  perc_inc  perc_cut  share_of_change
# bins
# (-100000000000000, 0]      0.000000e+00  0.000000  0.000000         0.000000
# (0, 9999]                  0.000000e+00  0.000000  0.000000         0.000000
# (9999, 19999]              0.000000e+00  0.000000  0.000000         0.000000
# (19999, 29999]             0.000000e+00  0.000000  0.000000         0.000000
# (29999, 39999]             0.000000e+00  0.000000  0.000000         0.000000
# (39999, 49999]             0.000000e+00  0.000000  0.000000         0.000000
# (49999, 74999]             0.000000e+00  0.000000  0.000000         0.000000
# (74999, 99999]             1.676004e+10  0.010508  0.000000         0.002686
# (99999, 200000]            9.997052e+11  0.119907  0.000001         0.160209
# (200000, 100000000000000]  5.223550e+12  0.805928  0.000054         0.837105
