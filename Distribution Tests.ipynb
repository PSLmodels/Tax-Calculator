# %%
from taxcalc import *
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook, hplot
from bokeh.charts import Scatter
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6e6689dc-9603-4194-88ff-65ddc1b59d50">Loading BokehJS ...</span>
#     </div>

# %%
recs = Records('ubi_puf.csv', weights='puf_weights.csv')
policy = Policy(start_year=2013)
calc = Calculator(policy=policy, records=recs)
# Out:
# You loaded data for 2009.
# Calculator instantiation automatically extrapolated your data to 2013.

# %%
calc.advance_to_year(2014)
calc.calc_all()

# %%
soi = pd.read_csv('soi_data.csv')

# %%
def distribution(item, weight, agi):
    agi_1 = (((item[agi < 0] * weight[agi < 0]).sum() / 1000))
    agi_2 = ((item[(agi > 1) & (agi < 5000)] * weight[(agi > 1) & (agi < 5000)]).sum() / 1000)
    agi_3 = ((item[(agi > 5000) & (agi < 10000)] * weight[(agi > 5000) & (agi < 10000)]).sum() / 1000)
    agi_4 = ((item[(agi > 10000) & (agi < 15000)] * weight[(agi > 10000) & (agi < 15000)]).sum() / 1000)
    agi_5 = ((item[(agi > 15000) & (agi < 20000)] * weight[(agi > 15000) & (agi < 20000)]).sum() / 1000)
    agi_6 = ((item[(agi > 20000) & (agi < 25000)] * weight[(agi > 20000) & (agi < 25000)]).sum() / 1000)
    agi_7 = ((item[(agi > 25000) & (agi < 30000)] * weight[(agi > 25000) & (agi < 30000)]).sum() / 1000)
    agi_8 = ((item[(agi > 30000) & (agi < 40000)] * weight[(agi > 30000) & (agi < 40000)]).sum() / 1000)
    agi_9 = ((item[(agi > 40000) & (agi < 50000)] * weight[(agi > 40000) & (agi < 50000)]).sum() / 1000)
    agi_10 = ((item[(agi > 50000) & (agi < 75000)] * weight[(agi > 50000) & (agi < 75000)]).sum() / 1000)
    agi_11 = ((item[(agi > 75000) & (agi < 100000)] * weight[(agi > 75000) & (agi < 100000)]).sum() / 1000)
    agi_12 = ((item[(agi > 100000) & (agi < 200000)] * weight[(agi > 100000) & (agi < 200000)]).sum() / 1000)
    agi_13 = ((item[(agi > 200000) & (agi < 500000)] * weight[(agi > 200000) & (agi < 500000)]).sum() / 1000)
    agi_14 = ((item[(agi > 500000) & (agi < 1000000)] * weight[(agi > 500000) & (agi < 1000000)]).sum() / 1000)
    agi_15 = ((item[(agi > 1000000) & (agi < 1500000)] * weight[(agi > 1000000) & (agi < 1500000)]).sum() / 1000)
    agi_16 = ((item[(agi > 1500000) & (agi < 2000000)] * weight[(agi > 1500000) & ( agi < 2000000)]).sum() / 1000)
    agi_17 = ((item[(agi > 2000000) & (agi < 5000000)] * weight[(agi > 2000000) & ( agi < 5000000)]).sum() / 1000)
    agi_18 = ((item[(agi > 5000000) & (agi < 10000000)] * weight[(agi > 5000000) & ( agi < 10000000)]).sum() / 1000)
    agi_19 = ((item[agi > 10000000] * weight[agi > 10000000]).sum() / 1000)
    total = ((item * weight).sum() / 1000)
    df = [agi_1, agi_2, agi_3, agi_4, agi_5, agi_6, agi_7, agi_8, agi_9, agi_10, agi_11,
                       agi_12, agi_13, agi_14, agi_15, agi_16, agi_17, agi_18, agi_19]
    return df

# %%
# Find totals for each item
tc = pd.DataFrame()
tc['AGI'] = distribution(calc.records.c00100, calc.records.s006, calc.records.c00100)
tc['Wages'] = distribution(calc.records.e00200, calc.records.s006, calc.records.c00100)
tc['Interest'] = distribution(calc.records.e00300, calc.records.s006, calc.records.c00100)
tc['Dividends'] = distribution(calc.records.e00650, calc.records.s006, calc.records.c00100)
tc['SchC'] = distribution(calc.records.e00900, calc.records.s006, calc.records.c00100)
tc['IRA'] = distribution(calc.records.e01400, calc.records.s006, calc.records.c00100)
tc['Scorp'] = distribution(calc.records.e26270, calc.records.s006, calc.records.c00100)
tc['SS Benefits'] = distribution(calc.records.e02400, calc.records.s006, calc.records.c00100)
tc['Item Ded'] = distribution(calc.records.c04470, calc.records.s006, calc.records.c00100)
tc['Inc'] = distribution(calc.records.c04800, calc.records.s006, calc.records.c00100)

# %%
# Create results DataFrame and file
results = pd.DataFrame()
results['SOI - AGI'] = soi['AGI']
results['TC - AGI'] = tc['AGI']
results['AGI % Error'] = (tc['AGI'] / soi['AGI'] - 1) * 100
results['SOI - Wages'] = soi['Wages']
results['TC - Wages'] = tc['Wages']
results['Wages % Error'] = (tc['Wages'] / soi['Wages'] - 1) * 100
results['SOI - Taxable Interest'] = soi['Interest']
results['TC - Taxable Interest'] = tc['Interest']
results['Taxable Interest % Error'] = (tc['Interest'] / soi['Interest'] - 1) * 100
results['SOI - Qualified Dividends'] = soi.Dividends
results['TC - Qualified Dividends'] = tc['Dividends']
results['Qualified Dividends % Error'] = (tc['Dividends'] / soi['Dividends'] - 1) * 100
results['SOI - Schedule C Net Income/Loss'] = soi['SchC']
results['TC - Schedule C Net Income/Loss'] = tc['SchC']
results['Sch C Net Income/Loss % Error'] = (tc['SchC'] / soi['SchC'] - 1) * 100
results['SOI - IRA Distributions'] = soi['IRA']
results['TC - IRA Distribtuions'] = tc['IRA']
results['IRA Distributions Error'] = (tc['IRA'] / soi['IRA'] - 1) * 100
results['SOI - S Corp Income'] = soi['Scorp']
results['TC - S Corp Income'] = tc['Scorp']
results['S Corp Income % Error'] = (tc['Scorp'] / soi['Scorp'] - 1) * 100
results['SOI - SS Benefits'] = soi['SS Benefits']
results['TC - SS Benefits'] = tc['SS Benefits']
results['SS Benefits % Error'] = (tc['SS Benefits'] / soi['SS Benefits'] - 1) * 100
results['SOI - Itemized Deductions'] = soi['Item Ded']
results['TC - Itemized Deduction'] = tc['Item Ded']
results['Itemized Deductions % Error'] = (tc['Item Ded'] / soi['Item Ded'] - 1) * 100
results['SOI - Taxable Income'] = soi['Inc']
results['TC - Taxable Income'] = tc['Inc']
results['Taxable Income % Error'] = (tc['Inc'] / soi['Inc'] - 1) * 100

# %%
index_list = ['Zero or Negative',
              '$1-$5K',
              '$5K-$10K',
              '$10K-$15K',
              '$15K-$20K',
              '$20K-$25K',
              '$25K-$30K',
              '$30K-$40K',
              '$40K-$50K',
              '$50K-$75K',
              '$75K-$100K',
              '$100K-$200K',
              '$200K-$500K',
              '$500K-$1M',
              '$1M-$1.5M',
              '$1.5M-$2M',
              '$2M-$5M',
              '$5M-$10M',
              '$10M and over']
# $500K-$1M                  7.443340e+06                  9.232305
# $1M-$1.5M                  3.523179e+06                 -7.914225
# $1.5M-$2M                  2.755061e+06                  6.694768
# $2M-$5M                    7.733261e+06                  8.940531
# $5M-$10M                   4.781107e+06                  5.133996
# $10M and over              2.116444e+07                 22.146716
#
#                   SOI - Qualified Dividends           ...            \
# Zero or Negative                    3095521           ...
# $1-$5K                               639115           ...
# $5K-$10K                             859292           ...
# $10K-$15K                           1137469           ...
# $15K-$20K                           1137002           ...
# $20K-$25K                           1234331           ...
# $25K-$30K                           1183817           ...
# $30K-$40K                           2794332           ...
# $40K-$50K                           2996252           ...
# $50K-$75K                           9906058           ...
# $75K-$100K                          9921453           ...
# $100K-$200K                        31985381           ...
# $200K-$500K                        34400475           ...
# $500K-$1M                          19243443           ...
# $1M-$1.5M                           8124591           ...
# $1.5M-$2M                           5750856           ...
# $2M-$5M                            14940470           ...
# $5M-$10M                            8846877           ...
# $10M and over                      34250973           ...
#
#                   S Corp Income % Error  SOI - SS Benefits  TC - SS Benefits  \
# Zero or Negative             241.401549           16387413      1.416185e+07
# $1-$5K                       525.548618           30462629      1.076512e+08
# $5K-$10K                     119.075292           35764379      6.336986e+07
# $10K-$15K                   -125.952947           41628764      5.769459e+07
# $15K-$20K                   -116.503921           36611936      4.246904e+07
# $20K-$25K                      0.352260           31287885      3.416411e+07
# $25K-$30K                    145.993561           26673890      2.957527e+07
# $30K-$40K                    -64.556973           43890297      4.787185e+07
# $40K-$50K                      3.983191           35702308      3.770930e+07
# $50K-$75K                    -14.843329           83556997      8.053171e+07
# $75K-$100K                   -24.953733           67427955      5.893351e+07
# $100K-$200K                  -13.631390           92077062      6.970969e+07
# $200K-$500K                   -1.285958           26754538      2.006669e+07
# $500K-$1M                     13.806025            4376576      4.218526e+06
# $1M-$1.5M                     22.840516            1057199      1.235906e+06
# $1.5M-$2M                     39.351499             473501      5.577295e+05
# $2M-$5M                       26.503134             699604      9.221962e+05
# $5M-$10M                      32.411034             175151      2.434975e+05
# $10M and over                -17.517679             118834      1.330851e+05
#
#                   SS Benefits % Error  SOI - Itemized Deductions  \
# Zero or Negative           -13.580920                          0
# $1-$5K                     253.387657                    5288726
# $5K-$10K                    77.187084                    6356107
# $10K-$15K                   38.593086                    9183481
# $15K-$20K                   15.997794                   13507422
# $20K-$25K                    9.192762                   14020331
# $25K-$30K                   10.877229                   18200485
# $30K-$40K                    9.071591                   41001388
# $40K-$50K                    5.621455                   48792280
# $50K-$75K                   -3.620626                  137812627
# $75K-$100K                 -12.597813                  145398198
# $100K-$200K                -24.292015                  344438245
# $200K-$500K                -24.997059                  200106262
# $500K-$1M                   -3.611279                   64254359
# $1M-$1.5M                   16.903802                   23410404
# $1.5M-$2M                   17.788463                   13901555
# $2M-$5M                     31.816888                   34241999
# $5M-$10M                    39.021454                   19531052
# $10M and over               11.992462                   67260164
#
#                   TC - Itemized Deduction  Itemized Deductions % Error  \
# Zero or Negative             6.719763e+03                          inf
# $1-$5K                       3.458074e+04                   -99.346142
# $5K-$10K                     2.663401e+05                   -95.809697
# $10K-$15K                    4.981969e+06                   -45.750761
# $15K-$20K                    8.318782e+06                   -38.413250
# $20K-$25K                    1.195134e+07                   -14.757093
# $25K-$30K                    1.497535e+07                   -17.720024
# $30K-$40K                    3.641140e+07                   -11.194725
# $40K-$50K                    4.587942e+07                    -5.969916
# $50K-$75K                    1.305856e+08                    -5.244080
# $75K-$100K                   1.260208e+08                   -13.327151
# $100K-$200K                  3.457494e+08                     0.380665
# $200K-$500K                  2.177494e+08                     8.816891
# $500K-$1M                    6.084633e+07                    -5.303967
# $1M-$1.5M                    2.298813e+07                    -1.803792
# $1.5M-$2M                    1.233348e+07                   -11.279835
# $2M-$5M                      2.918004e+07                   -14.782886
# $5M-$10M                     1.529057e+07                   -21.711491
# $10M and over                2.112756e+07                   -68.588309
#
#                   SOI - Taxable Income  TC - Taxable Income  \
# Zero or Negative                     0         0.000000e+00
# $1-$5K                          540176         4.485222e+05
# $5K-$10K                       3617249         2.608670e+06
# $10K-$15K                     18153883         1.685358e+07
# $15K-$20K                     44114832         3.859128e+07
# $20K-$25K                     71604080         5.694638e+07
# $25K-$30K                     98280801         9.062703e+07
# $30K-$40K                    253424537         2.275980e+08
# $40K-$50K                    299205654         2.733914e+08
# $50K-$75K                    771635427         7.558472e+08
# $75K-$100K                   779971010         7.088014e+08
# $100K-$200K                 1782744296         1.810279e+09
# $200K-$500K                 1170539854         1.309786e+09
# $500K-$1M                    497846020         5.651378e+08
# $1M-$1.5M                    193923952         2.569576e+08
# $1.5M-$2M                    118522116         1.561472e+08
# $2M-$5M                      292433227         4.024967e+08
# $5M-$10M                     162522073         2.272091e+08
# $10M and over                438776456         4.370110e+08
#
#                   Taxable Income % Error
# Zero or Negative                     NaN
# $1-$5K                        -16.967396
# $5K-$10K                      -27.882481
# $10K-$15K                      -7.162683
# $15K-$20K                     -12.520851
# $20K-$25K                     -20.470480
# $25K-$30K                      -7.787658
# $30K-$40K                     -10.191028
# $40K-$50K                      -8.627587
# $50K-$75K                      -2.046076
# $75K-$100K                     -9.124644
# $100K-$200K                     1.544489
# $200K-$500K                    11.895902
# $500K-$1M                      13.516579
# $1M-$1.5M                      32.504320
# $1.5M-$2M                      31.745215
# $2M-$5M                        37.637130
# $5M-$10M                       39.801982
# $10M and over                  -0.402353
#
# [19 rows x 30 columns]

# %% [markdown]
# ## Distributions

# %% [markdown]
# ### AGI

# %%
soi_agi = pd.DataFrame()
soi_agi['Percent of Total AGI'] = soi['AGI'] / soi['AGI'].sum()
soi_agi['Measure'] = 'SOI'
soi_agi['AGI Bin'] = index_list
tc_agi = pd.DataFrame()
tc_agi['Percent of Total AGI'] = tc['AGI'] / tc['AGI'].sum()
tc_agi['Measure'] = 'TC'
tc_agi['AGI Bin'] = index_list
data_agi = [soi_agi, tc_agi]
plot_data_agi = pd.concat(data_agi)
plot_agi = Scatter(plot_data_agi, x='AGI Bin', y='Percent of Total AGI', color='Measure', 
                   title='Percent of Total AGI by AGI Bin')
show(plot_agi)

soi_agi_sum = pd.DataFrame()
soi_agi_sum['Total AGI'] = soi['AGI']
soi_agi_sum['Measure'] = 'SOI'
soi_agi_sum['AGI Bin'] = index_list
tc_agi_sum = pd.DataFrame()
tc_agi_sum['Total AGI'] = tc['AGI']
tc_agi_sum['Measure'] = 'TC'
tc_agi_sum['AGI Bin'] = index_list
data_agi_sum = [soi_agi_sum, tc_agi_sum]
plot_data_agi_sum = pd.concat(data_agi_sum)
plot_agi_sum = Scatter(plot_data_agi_sum, x='AGI Bin', y='Total AGI', color='Measure', 
                   title='Total AGI by AGI Bin')
show(plot_agi_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="57808a9f-3988-4f34-9e71-57d429910a49"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("57808a9f-3988-4f34-9e71-57d429910a49").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("57808a9f-3988-4f34-9e71-57d429910a49");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '57808a9f-3988-4f34-9e71-57d429910a49' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"40e92d59-7495-4f93-a490-b658d268af32":{"roots":{"references":[{"attributes":{"data_source":{"id":"76a7cc40-7798-4182-a12b-0abf60702936","type":"ColumnDataSource"},"glyph":{"id":"f83b16f6-2ad7-4999-98ff-7034d481bd12","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"15540bc0-5c3b-41c2-9d9a-8df74d656dc5","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"79f4a793-73a7-4b8b-926d-d7b9ceae08a8","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":"Percent of Total AGI by AGI Bin"},"id":"8fdad785-19dc-4f17-a01a-78d0cfb1ef4a","type":"Title"},{"attributes":{"data_source":{"id":"145194a5-52ca-4822-93e4-3a9d52c406c3","type":"ColumnDataSource"},"glyph":{"id":"483c8714-f685-44bd-a8af-82c476b3cb13","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"39e08724-fa13-4950-a386-7b4bb71c9f32","type":"GlyphRenderer"},{"attributes":{"label":{"value":"SOI"},"renderers":[{"id":"15540bc0-5c3b-41c2-9d9a-8df74d656dc5","type":"GlyphRenderer"}]},"id":"b55c4394-4ed8-4d9d-aae0-7f7b274e4fc8","type":"LegendItem"},{"attributes":{},"id":"352ad743-e2d7-42b7-82d6-559b6b46697e","type":"CategoricalTickFormatter"},{"attributes":{"label":{"value":"TC"},"renderers":[{"id":"39e08724-fa13-4950-a386-7b4bb71c9f32","type":"GlyphRenderer"}]},"id":"394d28ee-8648-47c5-a4fa-80cfcd88a6a1","type":"LegendItem"},{"attributes":{"overlay":{"id":"79f4a793-73a7-4b8b-926d-d7b9ceae08a8","type":"BoxAnnotation"},"plot":{"id":"5da3e13c-533f-4300-81d1-c0c9d7d0019b","subtype":"Chart","type":"Plot"}},"id":"ae0cb01d-f427-4cbd-b265-a2d4d7c4eb78","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"5da3e13c-533f-4300-81d1-c0c9d7d0019b","subtype":"Chart","type":"Plot"},"ticker":{"id":"c6f40eb8-2506-4729-baf0-4a17df234e54","type":"BasicTicker"}},"id":"8d372dbd-7a36-4528-a6b4-2fac1d434732","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"483c8714-f685-44bd-a8af-82c476b3cb13","type":"Circle"},{"attributes":{},"id":"c6f40eb8-2506-4729-baf0-4a17df234e54","type":"BasicTicker"},{"attributes":{"plot":{"id":"5da3e13c-533f-4300-81d1-c0c9d7d0019b","subtype":"Chart","type":"Plot"}},"id":"7cec4a19-5eb9-4f8b-8c36-65c94b764d54","type":"PanTool"},{"attributes":{"callback":null,"factors":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"]},"id":"ec9db384-125f-416d-91f5-e64c9fced736","type":"FactorRange"},{"attributes":{"axis_label":"AGI Bin","formatter":{"id":"352ad743-e2d7-42b7-82d6-559b6b46697e","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":
type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC","TC"],"chart_index":[{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":{"__ndarray__":"E1DhWAbvocGLuGSegbaCQUg1oYo3aZdBrLtOXd+fokEvOLzs8KKmQQHdQgWL1KZBSJVlHI+nq0GM9myYwC67QZ4m4dbor7tBUakYYPMy0UGsRBxO1PHNQTgMmNWi1eFBRM8VIluY10GG4oV8rq3CQaXXPYTfr7BBo2RMhsoYpEGu6sQ967q5QUJMZEfT6KxBWf8e9udOu0E=","dtype":"float64","shape":[19]}}},"id":"1cb23620-9966-4479-b29b-c77f0822b3ed","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"be39405a-6595-473c-9930-a8591e59cbc6","type":"PanTool"},{"id":"bb0925f5-a7fb-49be-b41e-7027c24f023b","type":"WheelZoomTool"},{"id":"dd911b49-0c4f-43d8-b24d-a1df3c7311d9","type":"BoxZoomTool"},{"id":"8f7e4452-ba89-4c8e-8f2c-b25513 ...

# %% [markdown]
# ### Wages and Salaries

# %%
soi_wage = pd.DataFrame()
soi_wage['Percent of Total Wage and Salaries Income'] = soi['Wages'] / soi['Wages'].sum()
soi_wage['Measure'] = 'SOI'
soi_wage['AGI Bin'] = index_list
tc_wage = pd.DataFrame()
tc_wage['Percent of Total Wage and Salaries Income'] = tc['Wages'] / tc['Wages'].sum()
tc_wage['Measure'] = 'TC'
tc_wage['AGI Bin'] = index_list
data_wage = [soi_wage, tc_wage]
plot_data_wage = pd.concat(data_wage)
plot_wage = Scatter(plot_data_wage, x='AGI Bin', y='Percent of Total Wage and Salaries Income', color='Measure',
                    title = 'Percent of Total Wages and Salaries by AGI Bin')
show(plot_wage)

soi_wage_sum = pd.DataFrame()
soi_wage_sum['Total Wage and Salaries Income'] = soi['Wages']
soi_wage_sum['Measure'] = 'SOI'
soi_wage_sum['AGI Bin'] = index_list
tc_wage_sum = pd.DataFrame()
tc_wage_sum['Total Wage and Salaries Income'] = tc['Wages']
tc_wage_sum['Measure'] = 'TC'
tc_wage_sum['AGI Bin'] = index_list
data_wage_sum = [soi_wage_sum, tc_wage_sum]
plot_data_wage_sum = pd.concat(data_wage_sum)
plot_wage_sum = Scatter(plot_data_wage_sum, x='AGI Bin', y='Total Wage and Salaries Income', color='Measure',
                    title = 'Total Wages and Salaries by AGI Bin')
show(plot_wage_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b691c8f6-3071-4a1c-8032-5e4d202254fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b691c8f6-3071-4a1c-8032-5e4d202254fb").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b691c8f6-3071-4a1c-8032-5e4d202254fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b691c8f6-3071-4a1c-8032-5e4d202254fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9b42c47e-d4e7-4615-8f66-ede05ca566db":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"efa6a246-02b9-4549-9057-6f54712d3c21","type":"Circle"},{"attributes":{"axis_label":"Percent of Total Wage and Salaries Income","formatter":{"id":"03c1fd6b-51f0-4bb0-8b18-4204e3aae004","type":"BasicTickFormatter"},"plot":{"id":"5963455a-4abd-46b5-ac00-560b31ce3202","subtype":"Chart","type":"Plot"},"ticker":{"id":"cc0233a3-25bc-4130-819e-764f8c416d03","type":"BasicTicker"}},"id":"2e740a04-9c50-4094-b97f-312aed10e3fe","type":"LinearAxis"},{"attributes":{"plot":{"id":"5963455a-4abd-46b5-ac00-560b31ce3202","subtype":"Chart","type":"Plot"}},"id":"e9794044-aca6-4bcf-9a49-fcd601f652f4","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"
"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"},{"Measure":"TC"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":{"__ndarray__":"LDAy9QCbb0Eqf+IINFR3QWyoLPfv4YpBtzLgz3mdlUE+Su26HCmeQSNy7cQAXaBBX1jyGwSHpUGFZlyOQPO0QYqhlhc7QrVB32QUsysXykE5AwCKfnjGQWkjMspjMtxBfw8Z5zLk0EGMWa42lHm0Qc0QgKniJ55BU13CofZpjkHYM0vz6SChQYW6rkW3EJBBy/2knwohk0E=","dtype":"float64","shape":[19]}}},"id":"7913bc8d-e825-433c-b720-8c406bca1b7e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7913bc8d-e825-433c-b720-8c406bca1b7e","type":"ColumnDataSource"},"glyph":{"id":"98dbf4f6-416d-4f75-8e2b-d735c06afe93","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f367ebdb-a1bc-4a6e-9c9a-6c2a80f26e29","type":"GlyphRenderer"},{"attributes":{"label":{"value":"SOI"},"renderers":[{"id":"c493137a-7b93-48b5-92fb-e0bb262a63e7","type":"GlyphRenderer"}]},"id":"1ec114cd-99bc-4941-b024-a65b1471a4c6","type":"LegendItem"},{"attributes":{},"id":"cd5bdb76-a6c9-4dbe-b4fb-4b03c8808bf5","type":"ToolEvents"},{"attributes":{},"id":"40ef1cd4-4457-4281-8a5d-687ce7a7d42b","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"ab69abf5-1583-4baa-848d-c392041a6d07","subtype":"Chart","type":"Plot"}},"id":"779621c3-1ac3-4af2-b02f-4de1eaabbdd5","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":2079826296.8955147,"start":-170998344.449727},"id":"bdecc1dc-508d-406d-ad4a-10675605475f","type":"Range1d"},{"attributes":{"axis_label":"Total Wage and Salaries Income","formatter":{"id":"90cd0002-0698-43d1-9502-a788394bd579","type":"BasicTickFormatter"},"plot":{"id":"ab69abf5-1583-4baa-848d-c392041a6d07","subtype":"Chart","type":"Plot"},"ticker":{"id":"5a00c8ab-a956-49a8-9dfc-64c9b1df63b8","type":"BasicTicker"}},"id":"0c01d347-6ba8-49d0-8627-6bc5fb2f5db3","type":"LinearAxis"},{"attributes":{"items":[{"id":"1ec114cd-99bc-4941-b024-a65b1471a4c6","type":"LegendItem"},{"id":"026d7dc3-5931-4bf1-95f4-1248daf59cdf","type":"LegendItem"}],"location":"top_left","plot":{"id":"ab69abf5-1583-4baa-848d-c392041a6d07","subtype":"Chart","type":"Plot"}},"id":"8393fc35-797b-4f25-a9c8-fb3cf3618b51","type":"Legend"},{"attributes":{"callback":null,"factors":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"]},"id":"b4fa819b-45c7-4e9c-b1a5-585c3217c8fa","type":"FactorRange"},{"attributes":{},"id":"5a00c8ab-a956-49a8-9dfc-64c9b1df63b8","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI"],"chart_index":[{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measu ...

# %% [markdown]
# ### Taxable Interest

# %%
soi_int = pd.DataFrame()
soi_int['Percent of Total Interest Income'] = soi['Interest'] / soi['Interest'].sum()
soi_int['Measure'] = 'SOI'
soi_int['AGI Bin'] = index_list
tc_int = pd.DataFrame()
tc_int['Percent of Total Interest Income'] = tc['Interest'] / tc['Interest'].sum()
tc_int['Measure'] = 'TC'
tc_int['AGI Bin'] = index_list
data_int = [soi_int, tc_int]
plot_data_int = pd.concat(data_int)
plot_int = Scatter(plot_data_int, x='AGI Bin', y='Percent of Total Interest Income', color='Measure',
                    title = 'Percent of Total Interest Income by AGI Bin')
show(plot_int)

soi_int_sum = pd.DataFrame()
soi_int_sum['Total Interest Income'] = soi['Interest']
soi_int_sum['Measure'] = 'SOI'
soi_int_sum['AGI Bin'] = index_list
tc_int_sum = pd.DataFrame()
tc_int_sum['Total Interest Income'] = tc['Interest']
tc_int_sum['Measure'] = 'TC'
tc_int_sum['AGI Bin'] = index_list
data_int_sum = [soi_int_sum, tc_int_sum]
plot_data_int_sum = pd.concat(data_int_sum)
plot_int_sum = Scatter(plot_data_int_sum, x='AGI Bin', y='Total Interest Income', color='Measure',
                    title = 'Total Interest Income by AGI Bin')
show(plot_int_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
plot":{"id":"d5157b75-1413-4ae1-a8b5-f92904300d6e","subtype":"Chart","type":"Plot"}},"id":"3f44ec27-6af0-4a5f-baf3-44a75ada5c55","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"d5157b75-1413-4ae1-a8b5-f92904300d6e","subtype":"Chart","type":"Plot"}},"id":"98704d7e-47f8-46fd-ad94-aea8996d60a7","type":"HelpTool"},{"attributes":{"items":[{"id":"e50c7439-25d3-41a8-8b41-4bee9e7a3402","type":"LegendItem"},{"id":"abedb1b7-1c62-476f-a0a8-24aeda7471df","type":"LegendItem"}],"location":"top_left","plot":{"id":"d5157b75-1413-4ae1-a8b5-f92904300d6e","subtype":"Chart","type":"Plot"}},"id":"c4aed6a7-1275-44ae-bda0-a839d8ee8595","type":"Legend"},{"attributes":{"plot":{"id":"d5157b75-1413-4ae1-a8b5-f92904300d6e","subtype":"Chart","type":"Plot"},"ticker":{"id":"cac605d5-33e8-4dd7-9391-bdfb89318b6f","type":"CategoricalTicker"}},"id":"607c7012-1ab3-443b-858f-4f7dad7ae0b4","type":"Grid"},{"attributes":{"overlay":{"id":"5f25e66 ...

# %% [markdown]
# ### Qualified Dividends

# %%
soi_div = pd.DataFrame()
soi_div['Percent of Total Dividend Income'] = soi['Dividends'] / soi['Dividends'].sum()
soi_div['Measure'] = 'SOI'
soi_div['AGI Bin'] = index_list
tc_div = pd.DataFrame()
tc_div['Percent of Total Dividend Income'] = tc['Dividends'] / tc['Dividends'].sum()
tc_div['Measure'] = 'TC'
tc_div['AGI Bin'] = index_list
data_div = [soi_div, tc_div]
plot_data_div = pd.concat(data_div)
plot_div = Scatter(plot_data_div, x='AGI Bin', y='Percent of Total Dividend Income', color='Measure',
                    title = 'Percent of Total Qualified Dividends Distribution by AGI Bin')
show(plot_div)

soi_div_sum = pd.DataFrame()
soi_div_sum['Total Dividend Income'] = soi['Dividends']
soi_div_sum['Measure'] = 'SOI'
soi_div_sum['AGI Bin'] = index_list
tc_div_sum = pd.DataFrame()
tc_div_sum['Total Dividend Income'] = tc['Dividends']
tc_div_sum['Measure'] = 'TC'
tc_div_sum['AGI Bin'] = index_list
data_div_sum = [soi_div_sum, tc_div_sum]
plot_data_div_sum = pd.concat(data_div_sum)
plot_div_sum = Scatter(plot_data_div_sum, x='AGI Bin', y='Total Dividend Income', color='Measure',
                    title = 'Total Qualified Dividends Distribution by AGI Bin')
show(plot_div_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cc1ac9e1-c615-4d60-a8ac-40762f2cb2dc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cc1ac9e1-c615-4d60-a8ac-40762f2cb2dc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cc1ac9e1-c615-4d60-a8ac-40762f2cb2dc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cc1ac9e1-c615-4d60-a8ac-40762f2cb2dc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bdf8b74f-3c6e-4ae6-a107-eade8032a3ba":{"roots":{"references":[{"attributes":{"label":{"value":"SOI"},"renderers":[{"id":"c9ff5209-90e1-4305-8d63-5ab68b4e1188","type":"GlyphRenderer"}]},"id":"e6f70169-5358-48b9-906a-8b428a743e8f","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI"],"chart_index":[{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":{"__ndarray__":"szee8ZV4kD/tRVWXmTRrP4Im5Gv2SXI/nHg1R6U1eD++hj7iGTN4P8emkx9pRXo/TFIOuy0yeT8LSjNUo7yNP17FtkO74o8/UpYCps1aqj+PnFPcSWWqPwheWZQjRsU/mDw8LFvhxj8E6VDYJZm5P7zJJwJ8naU/R8KJqJGZnj/tDTIM0d+zPxu0qPpqiac/dHe+hubHxj8=","dtype":"float64","shape":[19]}}},"id":"fde94026-f46e-4bcf-b38d-19ecfd7d4d95","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":
type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4d33e8b0-6779-4be7-8b45-21fac8ce6009","type":"GlyphRenderer"},{"attributes":{"axis_label":"AGI Bin","formatter":{"id":"23528049-de15-4b02-83a8-bd1a2d863ae3","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"debb005b-24d0-42d0-afd7-0aacc24300a7","subtype":"Chart","type":"Plot"},"ticker":{"id":"7f1d6247-c8a6-4213-92d5-47da76f776ac","type":"CategoricalTicker"}},"id":"6667f018-2601-4c11-978d-2d27a5a9415a","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI"],"chart_index":[{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"}],"x_values":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"],"y_values":{"__ndarray__":"AAAAgPCdR0EAAAAAFoEjQQAAAAA4OSpBAAAAAD1bMUEAAAAAalkxQQAAAACb1TJBAAAAAEkQMkEAAAAArlFFQQAAAAAO3EZBAAAAQPHkYkEAAACgdexiQQAAAFDugH5BAAAA2EZngEEAAAAwG1pyQQAAAMAr/l5BAAAAABLwVUEAAADAJn9sQQAAAKDD32BBAAAA6AZVgEE=","dtype":"float64","shape":[19]}}},"id":"e5ba54d1-9b03-4270-a885-0d8d2fb5f9ec","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"debb005b-24d0-42d0-afd7-0aacc24300a7","subtype":"Chart","type":"Plot"},"ticker":{"id":"3dcde584-196d-42a1-910b-f31be3cf3364","type":"BasicTicker"}},"id":"1b8ad6e9-1506-4254-b356-0c2e44f3cc64","type":"Grid"},{"attributes":{},"id":"7f1d6247-c8a6-4213-92d5-47da76f776ac","type":"CategoricalTicker"},{"attributes":{"axis_label":"Total Dividend Income","formatter":{"id":"8549177d-8a45-4d2f-bbea-c282f67ac3fd","type":"BasicTickFormatter"},"plot":{"id":"debb005b-24d0-42d0-afd7-0aacc24300a7","subtype":"Chart","type":"Plot"},"ticker":{"id":"3dcde584-196d-42a1-910b-f31be3cf3364","type":"BasicTicker"}},"id":"c8b2af3b-a524-4605-8c74-a505404cebbe","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a22660ce-f111-4297-93a7-2f28576c0fd4","type":"BoxAnnotation"},{"attributes":{},"id":"abb19c37-cfd9-4786-b46d-4d4afb0fad15","type":"ToolEvents"},{"attributes":{"plot":{"id":"debb005b-24d0-42d0-afd7-0aacc24300a7","subtype":"Chart","type":"Plot"}},"id":"de0f809f-a5cb-4762-9dfe-1e655d7237ce","type":"HelpTool"},{"attributes":{"callback":null,"factors":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$5 ...

# %% [markdown]
# ### Schedule C Net Income/Loss

# %%
soi_schc = pd.DataFrame()
soi_schc['Percent of Total Schedule C Income'] = soi['SchC'] / soi['SchC'].sum()
soi_schc['Measure'] = 'SOI'
soi_schc['AGI Bin'] = index_list
tc_schc = pd.DataFrame()
tc_schc['Percent of Total Schedule C Income'] = tc['SchC'] / tc['SchC'].sum()
tc_schc['Measure'] = 'TC'
tc_schc['AGI Bin'] = index_list
data_schc = [soi_schc, tc_schc]
plot_data_schc = pd.concat(data_schc)
plot_schc = Scatter(plot_data_schc, x='AGI Bin', y='Percent of Total Schedule C Income', color='Measure',
                    title = 'Percent of Total Schedule C Income by AGI Bin')
show(plot_schc)

soi_schc_sum = pd.DataFrame()
soi_schc_sum['Total Schedule C Income'] = soi['SchC']
soi_schc_sum['Measure'] = 'SOI'
soi_schc_sum['AGI Bin'] = index_list
tc_schc_sum = pd.DataFrame()
tc_schc_sum['Total Schedule C Income'] = tc['SchC']
tc_schc_sum['Measure'] = 'TC'
tc_schc_sum['AGI Bin'] = index_list
data_schc_sum = [soi_schc_sum, tc_schc_sum]
plot_data_schc_sum = pd.concat(data_schc_sum)
plot_schc_sum = Scatter(plot_data_schc_sum, x='AGI Bin', y='Total Schedule C Income', color='Measure',
                    title = 'Total Schedule C Income by AGI Bin')
show(plot_schc_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
b8120b16c18","type":"LinearAxis"},{"id":"37d35f02-e952-4c01-b822-d278846eba21","type":"Grid"},{"id":"55889108-12c0-414a-a3f2-5105879f448c","type":"Grid"}],"title":{"id":"8648b67f-6bd2-4b92-91d6-e900f7f9d4a0","type":"Title"},"tool_events":{"id":"61f877a8-321c-43a5-8ae5-2b9a3b3f3560","type":"ToolEvents"},"toolbar":{"id":"d0c5a259-e23d-49dc-b67b-3cf3c1c9dea2","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"fc254abb-43bb-4e10-8d6d-99fab24abe3e","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"74890f56-1a04-4f7c-bd6b-25659707affb","type":"Range1d"}},"id":"07af8a5b-5d45-4a3e-9803-3b261b300439","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"969b1f5d-7e30-454a-bcf9-028a3c38248f","type":"BasicTicker"},{"attributes":{"label":{"value":"TC"},"renderers":[{"id":"e1c1d50e-eb4d-4ff2-aa98-f1731438e563","type":"GlyphRenderer"}]},"id":"9c38df01-72a7-4ea1-bb97-6b2e09db2f2f","type":"LegendItem"},{"attributes":{},"id":"61f877a8-321c-43a5-8ae5-2b9a3b3f3560","type":"ToolEvents"},{"attributes":{"callback":null,"end":74653803.80534619,"start":-21079649.858808152},"id":"74890f56-1a04-4f7c-bd6b-25659707affb","type":"Range1d"},{"attributes":{"axis_label":"AGI Bin","formatter":{"id":"89b9e8a6-8da1-4cfd-87d2-6f3ede4ffaaf","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"07af8a5b-5d45-4a3e-9803-3b261b300439","subtype":"Chart","type":"Plot"},"ticker":{"id":"9be1ab7a-0ee7-4b2c-bb68-303e2f03a63f","type":"CategoricalTicker"}},"id":"93420e26-1f25-4197-bfac-9a839b24631e","type":"CategoricalAxis"},{"attributes":{},"id":"2e823699-1c57-46c0-ab32-59d175302cf4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"07 ...

# %% [markdown]
# ### Taxable IRA Distributions

# %%
soi_ira = pd.DataFrame()
soi_ira['Percent of Taxable IRA Distributions'] = soi['IRA'] / soi['IRA'].sum()
soi_ira['Measure'] = 'SOI'
soi_ira['AGI Bin'] = index_list
tc_ira = pd.DataFrame()
tc_ira['Percent of Taxable IRA Distributions'] = tc['IRA'] / tc['IRA'].sum()
tc_ira['Measure'] = 'TC'
tc_ira['AGI Bin'] = index_list
data_ira = [soi_ira, tc_ira]
plot_data_ira = pd.concat(data_ira)
plot_ira = Scatter(plot_data_ira, x='AGI Bin', y='Percent of Taxable IRA Distributions', color='Measure',
                    title = 'Percent of Total Taxable IRA Distributions by AGI Bin')
show(plot_ira)

soi_ira_sum = pd.DataFrame()
soi_ira_sum['Total Taxable IRA Distributions'] = soi['IRA']
soi_ira_sum['Measure'] = 'SOI'
soi_ira_sum['AGI Bin'] = index_list
tc_ira_sum = pd.DataFrame()
tc_ira_sum['Total Taxable IRA Distributions'] = tc['IRA']
tc_ira_sum['Measure'] = 'TC'
tc_ira_sum['AGI Bin'] = index_list
data_ira_sum = [soi_ira_sum, tc_ira_sum]
plot_data_ira_sum = pd.concat(data_ira_sum)
plot_ira_sum = Scatter(plot_data_ira_sum, x='AGI Bin', y='Total Taxable IRA Distributions', color='Measure',
                    title = 'Total Taxable IRA Distributions by AGI Bin')
show(plot_ira_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f24be7ee-42bf-443a-8920-2598663bf68d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f24be7ee-42bf-443a-8920-2598663bf68d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"9c779fc4-0e76-41e5-910c-59c56dc6c93b","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"499f023e-ffdd-465e-bb24-0c5a69ff4e3a","type":"Range1d"}},"id":"260e6286-71be-47b4-bb4a-b3aef7702567","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"260e6286-71be-47b4-bb4a-b3aef7702567","subtype":"Chart","type":"Plot"}},"id":"1526706a-3cbe-4968-bb41-38d6ce55f77a","type":"SaveTool"},{"attributes":{"label":{"value":"SOI"},"renderers":[{"id":"7d464088-851c-4064-a5ad-0d2cf112fb01","type":"GlyphRenderer"}]},"id":"4a4cf497-b66f-426e-86b3-43f8b4a2124d","type":"LegendItem"},{"attributes":{"plot":null,"text":"Total Taxable IRA Distributions by AGI Bin"},"id":"fd96fbd4-7a78-4a6e-b1d9-1e3aaf57f90f","type":"Title"},{"attributes":{},"id":"0a113a8f-293b-4622-9e71-4a9901af2d5c","type":"CategoricalTickFormatter"},{"attributes":{},"id":"913075bb-73b9-4427-b06a-a1acf1cc2c0b","type":"ToolEvents"},{"attributes":{},"id":"5e89e332-dbe7-4a32-bbd2-4d61704a086e","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.7},"fill_co ...

# %% [markdown]
# ### S Corporation Income

# %%
soi_scorp = pd.DataFrame()
soi_scorp['Percent of Total S Corporation Income'] = soi['Scorp'] / soi['Scorp'].sum()
soi_scorp['Measure'] = 'SOI'
soi_scorp['AGI Bin'] = index_list
tc_scorp = pd.DataFrame()
tc_scorp['Percent of Total S Corporation Income'] = tc['Scorp'] / tc['Scorp'].sum()
tc_scorp['Measure'] = 'TC'
tc_scorp['AGI Bin'] = index_list
data_scorp = [soi_scorp, tc_scorp]
plot_data_scorp = pd.concat(data_scorp)
plot_scorp = Scatter(plot_data_scorp, x='AGI Bin', y='Percent of Total S Corporation Income', color='Measure',
                    title = 'Percent of Total S Corporation Income by AGI Bin')
show(plot_scorp)

soi_scorp_sum = pd.DataFrame()
soi_scorp_sum['Total S Corporation Income'] = soi['Scorp']
soi_scorp_sum['Measure'] = 'SOI'
soi_scorp_sum['AGI Bin'] = index_list
tc_scorp_sum = pd.DataFrame()
tc_scorp_sum['Total S Corporation Income'] = tc['Scorp']
tc_scorp_sum['Measure'] = 'TC'
tc_scorp_sum['AGI Bin'] = index_list
data_scorp_sum = [soi_scorp_sum, tc_scorp_sum]
plot_data_scorp_sum = pd.concat(data_scorp_sum)
plot_scorp_sum = Scatter(plot_data_scorp_sum, x='AGI Bin', y='Total S Corporation Income', color='Measure',
                    title = 'Total S Corporation Income by AGI Bin')
show(plot_scorp_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4fd06c01-9cf1-4fa2-82c1-cb7b894bc2fe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4fd06c01-9cf1-4fa2-82c1-cb7b894bc2fe").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4fd06c01-9cf1-4fa2-82c1-cb7b894bc2fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4fd06c01-9cf1-4fa2-82c1-cb7b894bc2fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1699e779-7bf2-44d1-9751-c7292d628673":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a5a00675-a1a8-4724-afe3-0d3c4f8e2cbd","type":"BoxAnnotation"},{"attributes":{},"id":"8e337a71-73d4-499c-8f6c-5a21e616e68b","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"AGI Bin","formatter":{"id":
# %% [markdown]
# ### Social Security Benefits

# %%
soi_ss = pd.DataFrame()
soi_ss['Percent of Total SS Benefits'] = soi['SS Benefits'] / soi['SS Benefits'].sum()
soi_ss['Measure'] = 'SOI'
soi_ss['AGI Bin'] = index_list
tc_ss = pd.DataFrame()
tc_ss['Percent of Total SS Benefits'] = tc['SS Benefits'] / tc['SS Benefits'].sum()
tc_ss['Measure'] = 'TC'
tc_ss['AGI Bin'] = index_list
data_ss = [soi_ss, tc_ss]
plot_data_ss = pd.concat(data_ss)
plot_ss = Scatter(plot_data_ss, x='AGI Bin', y='Percent of Total SS Benefits', color='Measure',
                    title = 'Percent of Total SS Benefits by AGI Bin')
show(plot_ss)

soi_ss_sum = pd.DataFrame()
soi_ss_sum['Total SS Benefits'] = soi['SS Benefits']
soi_ss_sum['Measure'] = 'SOI'
soi_ss_sum['AGI Bin'] = index_list
tc_ss_sum = pd.DataFrame()
tc_ss_sum['Total SS Benefits'] = tc['SS Benefits']
tc_ss_sum['Measure'] = 'TC'
tc_ss_sum['AGI Bin'] = index_list
data_ss_sum = [soi_ss_sum, tc_ss_sum]
plot_data_ss_sum = pd.concat(data_ss_sum)
plot_ss_sum = Scatter(plot_data_ss_sum, x='AGI Bin', y='Total SS Benefits', color='Measure',
                    title = 'Total SS Benefits by AGI Bin')
show(plot_ss_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="78874333-8469-4b4f-af23-47ff57d72762"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("78874333-8469-4b4f-af23-47ff57d72762").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("78874333-8469-4b4f-af23-47ff57d72762");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '78874333-8469-4b4f-af23-47ff57d72762' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f5f4c440-2707-4d5c-b4d3-a19795d9f295":{"roots":{"references":[{"attributes":{"plot":{"id":"7ccb0fa4-f0f3-4c67-80c5-04c7a2b3d082","subtype":"Chart","type":"Plot"}},"id":"ecc39ddb-50e0-4460-8dad-0a0203daa45a","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"fecdc783-5081-44db-97d9-590b0fbdfd42","type":"Circle"},{"attributes":{"data_source":{"id":"61c60c26-5b01-4bef-a9c8-415a2cdf0629","type":"ColumnDataSource"},"glyph":{"id":"fecdc783-5081-44db-97d9-590b0fbdfd42","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"79b9e578-c5b7-464b-b387-b19b484f1a4f","type":"GlyphRenderer"},{"attributes":{},"id":"0225822c-55ee-499c-ac0d-b45874046bd1","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"7ccb0fa4-f0f3-4c67-80c5-04c7a2b3d082","subtype":"Chart","type":"Plot"}},"id":"1442b9ff-ed49-4d15-8b36-1a286070de26","type":"SaveTool"},{"attributes":{},"id":"a2ed87c1-78f4-4020-a247-3f5a74ebf9f1","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"7ccb0fa4-f0f3-4c67-80c5-04c7a2b3d082","subtype":"Chart","type":"Plot"},"ticker":{"id":"b8ab4796-1734-447f-a870-8ed9dae46a44","type":"BasicTicker"}},"id":"bae0763a-8636-40dd-bb3a-70351253e719","type":"Grid"},{"attributes":{"plot":null,"text":"Percent of Total SS Benefits by AGI Bin"},"id":"9086321e-87b9-40de-b6b0-46c884aceb17","type":"Title"},{"attributes":{"plot":{"id":"7ccb0fa4-f0f3-4c67-80c5-04c7a2b3d082","subtype":"Chart","type":"Plot"},"ticker":{"id":"0225822c-55ee-499c-ac0d-b45874046bd1","type":"CategoricalTicker"}},"id":"603af998-5b02-48d1-8b17-3016f6855472","type":"Grid"},{"attributes":{"data_source":{"id":"09756af8-41fb-45d6-8a15-2fa9c00ad245","type":"ColumnDataSource"},"glyph":{"id":"f57ff087-0ae6-4fb8-b840-045c7e0480d1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":
95578506bfc","type":"LinearAxis"},{"id":"1979835c-a387-401f-9c07-c7a67c43ba25","type":"Grid"},{"id":"f01a35e4-a59d-453d-8762-e1015e36f76e","type":"Grid"}],"title":{"id":"bc959f0c-a86a-4f70-be30-c32f62cac944","type":"Title"},"tool_events":{"id":"7ffd3e14-ccc4-4d5d-ad18-7f21560911e6","type":"ToolEvents"},"toolbar":{"id":"2c7d4e54-d5be-4d8b-a31f-3765e344a0fb","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"60110fc1-98ae-4ada-a012-7cadef9303eb","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"1d6bc0f2-d274-498d-9432-a1a5dbfaf7c2","type":"Range1d"}},"id":"aec7eabe-f94e-48f3-a8ee-845103ab6337","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"7ffd3e14-ccc4-4d5d-ad18-7f21560911e6","type":"ToolEvents"},{"attributes":{},"id":"7bb9e2f0-adfd-491d-bc28-f6c1ae30ec6e","type":"CategoricalTickFormatter"},{"attributes":{},"id":"af7ab69c-efb5-4550-9a1c-ad8338c0ba40","type":"BasicTickFormatter"},{"attributes":{"callback":null,"factors":["Zero or Negative","$1-$5K","$5K-$10K","$10K-$15K","$15K-$20K","$20K-$25K","$25K-$30K","$30K-$40K","$40K-$50K","$50K-$75K","$75K-$100K","$100K-$200K","$200K-$500K","$500K-$1M","$1M-$1.5M","$1.5M-$2M","$2M-$5M","$5M-$10M","$10M and over"]},"id":"60110fc1-98ae-4ada-a012-7cadef9303eb","type":"FactorRange"},{"attributes":{"plot":{"id":"aec7eabe-f94e-48f3-a8ee-845103ab6337","subtype":"Chart","type":"Plot"}},"id":"e2f109f4-a34e-40e6-baaa-047d9c1cb90d","type":"HelpTool"},{"attributes":{"data_source":{"id":"82971220-9fcf-4ee6-a69f-c1b3759daa16","type":"ColumnDataSource"},"glyph":{"id":"bc7e5e8e-bcf2-418e-8b65-2814aa89a1c9","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6f3bef8b-94a0-464c-8130-f1a9b8d85567","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"fe10b5de-e2c9-41b5-aee6-3e73e7576941","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"90a7322e-a8d6-4bab-a44c-87e2dbd2acf4","type":"PanTool"},{"id":"4c82a74f-9911-4181-954e-e1427a0334d2","type":"WheelZoomTool"},{"id":"1437c8ef-ecfb-4d3d-93f7-b2899c70118c","type":"BoxZoomTool"},{"id":"57ce2190-3959-4b03-93b5-c5a1199f151b","type":"SaveTool"},{"id":"03d09401-23d4-48f1-ad47-291de11d5ebd","type":"ResetTool"},{"id":"e2f109f4-a34e-40e6-baaa-047d9c1cb90d","type":"HelpTool"}]},"id":"2c7d4e54-d5be-4d8b-a31f-3765e344a0fb","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_un ...

# %% [markdown]
# ### Total Itemized Deductions

# %%
soi_item = pd.DataFrame()
soi_item['Percent of Total Itemized Deductions'] = soi['Item Ded'] / soi['Item Ded'].sum()
soi_item['Measure'] = 'SOI'
soi_item['AGI Bin'] = index_list
tc_item = pd.DataFrame()
tc_item['Percent of Total Itemized Deductions'] = tc['Item Ded'] / tc['Item Ded'].sum()
tc_item['Measure'] = 'TC'
tc_item['AGI Bin'] = index_list
data_item = [soi_item, tc_item]
plot_data_item = pd.concat(data_item)
plot_item = Scatter(plot_data_item, x='AGI Bin', y='Percent of Total Itemized Deductions', color='Measure',
                    title = 'Percent of Total Itemized Deductions by AGI Bin')
show(plot_item)

soi_item_sum = pd.DataFrame()
soi_item_sum['Total Itemized Deductions'] = soi['Item Ded']
soi_item_sum['Measure'] = 'SOI'
soi_item_sum['AGI Bin'] = index_list
tc_item_sum = pd.DataFrame()
tc_item_sum['Total Itemized Deductions'] = tc['Item Ded']
tc_item_sum['Measure'] = 'TC'
tc_item_sum['AGI Bin'] = index_list
data_item_sum = [soi_item_sum, tc_item_sum]
plot_data_item_sum = pd.concat(data_item_sum)
plot_item_sum = Scatter(plot_data_item_sum, x='AGI Bin', y='Total Itemized Deductions', color='Measure',
                    title = 'Total Itemized Deductions by AGI Bin')
show(plot_item_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"51d24bff-71b8-4bf0-9b4c-c4861f74c6a8","subtype":"Chart","type":"Plot"},"ticker":{"id":"db465e7e-6a24-46a1-8a5c-e0cfdc6439b0","type":"BasicTicker"}},"id":"52b7e998-cf4c-4312-bc2f-2bdfb57c330e","type":"Grid"},{"attributes":{},"id":"dd5ad643-ad93-447a-ac88-9994dd283a96","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"51d24bff-71b8-4bf0-9b4c-c4861f74c6a8","subtype":"Chart","type":"Plot"},"ticker":{"id":"17632e60-816b-4ce3-839f-050887e206f4","type":"CategoricalTicker"}},"id":"03ec0360-6d82-4864-acb5-bd46a97e0742","type":"Grid"},{"attributes":{"overlay":{"id":"e1b500c1-e6e4-4db8-9472-30b281302024","type":"BoxAnnotation"},"plot":{"id":"51d24bff-71b8-4bf0-9b4c-c4861f74c6a8","subtype":"Chart","type":"Plot"}},"id":"b98cd31e-5940-4ff8-9a3e-396c90719fc0","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI"],"chart_index":[{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure":"SOI"},{"Measure" ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="747fda70-b69a-4b92-9d64-b5370e8932b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("747fda70-b69a-4b92-9d64-b5370e8932b6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("747fda70-b69a-4b92-9d64-b5370e8932b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '747fda70-b69a-4b92-9d64-b5370e8932b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"26ce4f13-ee9b-424b-9234-c24131451e9d":{"roots":{"references":[{"attributes":{"plot":{"id":"69f19c06-fee2-4593-87c8-8d0767b7a498","subtype":"Chart","type":"Plot"}},"id":"e51b8764-23dd-495e-9f6d-82e8d38e8989","type":"WheelZoomTool"},{"attributes":{"items":[{"id":"1b07be05-2b11-4443-938c-7099f4d4c453","type":"LegendItem"},{"id":"0af7cc42-3670-478e-ad4e-2fc192ea805d","type":"LegendItem"}],"location":"top_left","plot":{"id":"69f19c06-fee2-4593-87c8-8d0767b7a498","subtype":"Chart","type":"Plot"}},"id":"3d4a39d4-a539-4fa8-927c-1ea3bb86a36f","type":"Legend"},{"attributes":{},"id":"c4ca7600-32d8-45ae-bb8c-fc50dc5fb149","type":"ToolEvents"},{"attributes":{"below":[{"id":"c266a5d9-418d-4e5a-a400-8d44a7eec363","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"3dfbb0c8-d14e-4cb9-9d89-6d7da24553b6","type":"LinearAxis"}],"renderers":[{"id":"8dbe7712-9440-4ac4-867a-093cc817f28e","type":"BoxAnnotation"},{"id":"06684593-dcb7-4080-91ba-2de3ba89f05d","type":"GlyphRenderer"},{"id":"f1fe3405-2f46-4fb5-a42f-2a0e8c7be284","type":"GlyphRenderer"},{"id":"3d4a39d4-a539-4fa8-927c-1ea3bb86a36f","type":"Legend"},{"id":"c266a5d9-418d-4e5a-a400-8d44a7eec363","type":"CategoricalAxis"},{"id":"3dfbb0c8-d14e-4cb9-9d89-6d7da24553b6","type":"LinearAxis"},{"id":"66dfc411-9434-47a7-a693-ffafe92c11e0","type":"Grid"},{"id":"483ceabd-01ba-4c32-ad0c-2f656873471e","type":"Grid"}],"title":{"id":"1a403282-6d9d-4980-8c73-c7954b58f85f","type":"Title"},"tool_events":{"id":"c4ca7600-32d8-45ae-bb8c-fc50dc5fb149","type":"ToolEvents"},"toolbar":{"id":"2670515c-b96f-4be1-be37-126cede6110f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"64df7a78-dc5e-4744-bc2c-8defbd1e0f1e","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"7540baba-fe87-4e70-826f-b97be63352d6","type":"Range1d"}},"id":"69f19c06-fee2-4593-87c8-8d0767b7a498","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2604bc6d-a38c-4ac7-98a9-3bcaa487498c","type":"Circle"},{"attributes":{"data_source":{"id":"ca17c3fe-d24c-4973-a005-6a33302a5f34","type":"ColumnDataSource"},"glyph":{"id":"b929a590-4c27-4acf-b97b-e4761e68b468","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"06684593-dcb7-4080-91ba-2de3ba89f05d","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"8dbe7712-9440-4ac4-867a-093cc817f28e","type":"BoxAnnotation"},"plot":{"id":"69f19c06-fee2-4593-87c8-8d0767b7a498","subtype":"Chart","type":"Plot"}},"id":"489a43a6-2e47-4fc1-bf25-fb3adb73c7f7","type":"BoxZoomTool"},{"attributes":{"axis_label":"Total Itemized Deductions","formatter":{"id":"8e0e6b02-74e9-407e-b40c-3c0fb905f0a4","type":"BasicTickFormatter"},"plot":{"id":"69f19c06-fee2-4593-87c8-8d0767b7a498","subtype":"Chart","type":"Plot"},"ticker":{"id":"8821979b-cb3f-4917-8051-8a8806524820","type":"BasicTicker"}},"id":"3dfbb0c8-d14e-4cb9-9d89-6d7da24553b6","type":"LinearAxis"},{"attributes":{},"id":"8e0e6b02-74e9-407e-b40c-3c0fb905f0a4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"69f19c06-fee2-4593-87c8-8d0767b7a498","subtype":"Chart","type":"Plot"}},"id":"be503f82-fa1a-49f1-a8f9-8b6abd1fa9a7","type":"HelpTool"},{"attributes":{},"id":"8821979b-cb3f-4917-8051-8a8806524820","type":"BasicTicker"},{"attributes":{"axis_label":"AGI Bin","formatter":{"id":"d9e5b665-a67e-446d-8b9d-2fcf4758deb5","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"69f19c06-fee2-4593-87c8-8d0767b7a498","subtype":"Chart","type":"Plot"},"ticker":{"id":"6c627676-00cb-4edd-8430-0f0791ec834e","type":"CategoricalTicker"}},"id":"c266a5d9-418d-4e5a-a400-8d44a7eec363","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Measure":["SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SOI","SO ...

# %% [markdown]
# ### Taxable Income

# %%
soi_inc = pd.DataFrame()
soi_inc['Percent of Total Taxable Income'] = soi['Inc'] / soi['Inc'].sum()
soi_inc['Measure'] = 'SOI'
soi_inc['AGI Bin'] = index_list
tc_inc = pd.DataFrame()
tc_inc['Percent of Total Taxable Income'] = tc['Inc'] / tc['Inc'].sum()
tc_inc['Measure'] = 'TC'
tc_inc['AGI Bin'] = index_list
data_inc = [soi_inc, tc_inc]
plot_data_inc = pd.concat(data_inc)
plot_inc = Scatter(plot_data_inc, x='AGI Bin', y='Percent of Total Taxable Income', color='Measure',
                    title = 'Percent of Total Taxable Income by AGI Bin')
show(plot_inc)

soi_inc_sum = pd.DataFrame()
soi_inc_sum['Total Taxable Income'] = soi['Inc']
soi_inc_sum['Measure'] = 'SOI'
soi_inc_sum['AGI Bin'] = index_list
tc_inc_sum = pd.DataFrame()
tc_inc_sum['Total Taxable Income'] = tc['Inc']
tc_inc_sum['Measure'] = 'TC'
tc_inc_sum['AGI Bin'] = index_list
data_inc_sum = [soi_inc_sum, tc_inc_sum]
plot_data_inc_sum = pd.concat(data_inc_sum)
plot_inc_sum = Scatter(plot_data_inc_sum, x='AGI Bin', y='Total Taxable Income', color='Measure',
                    title = 'Total Taxable Income by AGI Bin')
show(plot_inc_sum)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id